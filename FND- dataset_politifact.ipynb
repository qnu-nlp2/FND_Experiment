# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('politifact.csv')
#df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#                 id                                           news_url  \
# 0  politifact14258  www.smoaky.com/forum/index.php?/topic/161489-b...
# 1  politifact14235  http://londonwebnews.com/2017/06/01/liberal-wo...
# 2  politifact15251  www.thesun.co.uk/news/5999912/buzz-aldrin-ufo-...
# 3  politifact14940  https://www.politico.com/story/2018/01/17/full...
# 4  politifact13687  http://politicot.com/mike-pence-allowing-rape-...
#
#                                                title  \
# 0  Barrels removed from Clinton property contain ...
# 1  Liberal Women Hate Me Because Of My “Striking ...
# 2  Buzz Aldrin ‘passes UFO lie detector test leav...
# 3   Full text: Jeff Flake on Trump speech transcript
# 4  Mike Pence: “Allowing Rape Victims To Have Abo...
#
#                                            news_body  count_like  count_share  \
# 0  Venezuelaâ€™s opposition has said that talks w...         648          385
# 1  When I was 16, my dad and I were parked outsid...         155          897
# 2  Tim Howard has said there was no dressing room...          45          347
# 3  The    home of Josiah Bartlett, a New Hampshir...         653          366
# 4  Las Vegas is due to witness its most surreal s...         325          556
#
#                                             user_ids label
# 0  877333304583651329\t877336178638241792\t877370...  real
# 1  871504202153025536\t871516797320790017\t871577...  real
# 2  983225226371698688\t983539473718771712\t983617...  real
# 3  922909748890128384\t922912974079188992\t922920...  real
# 4  754813199698960385\t754819164527730688\t754827...  real

# %%
from sklearn.feature_extraction.text import CountVectorizer

X = df["title"]+df["news_body"]+str(df["count_like"])+str(df["count_share"])+df["user_ids"]
y = df["label"]


vectorizer = CountVectorizer()

vectorizer.fit(X)
transformed = vectorizer.transform(X)
transformed
# Out:
# <1056x3375 sparse matrix of type '<class 'numpy.int64'>'
# 	with 9584 stored elements in Compressed Sparse Row format>

# %%
vectorizer.vocabulary_
# Out:
# {'breaking': 473,
#  'first': 1180,
#  'nfl': 2069,
#  'team': 2993,
#  'declares': 859,
#  'bankruptcy': 357,
#  'over': 2177,
#  'kneeling': 1704,
#  'thugs': 3052,
#  'court': 769,
#  'orders': 2157,
#  'obama': 2104,
#  'to': 3065,
#  'pay': 2221,
#  '400': 94,
#  'million': 1954,
#  'in': 1522,
#  'restitution': 2546,
#  'update': 3170,
#  'second': 2690,
#  'roy': 2621,
#  'moore': 1986,
#  'accuser': 138,
#  'works': 3342,
#  'for': 1209,
#  'michelle': 1937,
#  'right': 2574,
#  'now': 2090,
#  'oscar': 2166,
#  'pistorius': 2267,
#  'attempts': 317,
#  'commit': 694,
#  'suicide': 2929,
#  'trump': 3120,
#  'votes': 3226,
#  'death': 846,
#  'penalty': 2231,
#  'being': 397,
#  'gay': 1268,
#  'putin': 2410,
#  'says': 2667,
#  'pope': 2310,
#  'francis': 1229,
#  'is': 1605,
#  'not': 2084,
#  'man': 1859,
#  'of': 2117,
#  'god': 1305,
#  'must': 2021,
#  'see': 2697,
#  'new': 2061,
#  'york': 3358,
#  'wanted': 3243,
#  'infecting': 1542,
#  '240': 73,
#  'men': 1922,
#  'and': 240,
#  'women': 3333,
#  'with': 3325,
#  'hiv': 1447,
#  'saudi': 2660,
#  'arabia': 271,
#  'behead': 395,
#  'school': 2675,
#  'girls': 1294,
#  'their': 3028,
#  'male': 1854,
#  'friends': 1240,
#  'without': 3327,
#  'parents': 2201,
#  'or': 2153,
#  'guardian': 1351,
#  'malia': 1855,
#  'fired': 1175,
#  'from': 1242,
#  'cushy': 816,
#  'internship': 1576,
#  'at': 309,
#  'spanish': 2832,
#  'embassy': 1031,
#  'target': 2984,
#  'discontinue': 928,
#  'sale': 2646,
#  'holy': 1456,
#  'bible': 413,
#  'youngest': 3362,
#  'world': 3343,
#  'leader': 1751,
#  'bans': 360,
#  'george': 1278,
#  'soros': 2824,
#  'foundations': 1226,
#  'austria': 327,
#  'hillary': 1430,
#  'clinton': 659,
#  'has': 1388,
#  'third': 3040,
#  'heart': 1410,
#  'attack': 312,
#  'docs': 949,
#  'she': 2738,
#  'won': 3334,
#  'survive': 2952,
#  'barack': 361,
#  'tweets': 3136,
#  'sick': 2768,
#  'on': 2135,
#  'john': 1652,
#  'mccain': 1894,
#  'he': 1402,
#  'should': 2757,
#  'have': 1395,
#  'died': 914,
#  'president': 2344,
#  'underscores': 3154,
#  'us': 3177,
#  'jamaica': 1623,
#  'relations': 2496,
#  'actress': 148,
#  'sandra': 2652,
#  'bullock': 500,
#  'if': 1500,
#  'you': 3359,
#  'don': 960,
#  'like': 1795,
#  'our': 2169,
#  'can': 529,
#  'leave': 1761,
#  'never': 2060,
#  'come': 685,
#  'back': 345,
#  'again': 175,
#  'are': 274,
#  'one': 2137,
#  'jealous': 1631,
#  'woman': 3332,
#  'who': 3299,
#  'ls': 1835,
#  'nothing': 2086,
#  'compare': 701,
#  'hope': 1465,
#  'will': 3311,
#  'arrest': 284,
#  'gretchen': 1338,
#  'carlson': 551,
#  'the': 3027,
#  '2nd': 83,
#  'amendment': 229,
#  'was': 3256,
#  'written': 3350,
#  'before': 389,
#  'guns': 1358,
#  'were': 3287,
#  'invented': 1584,
#  'mass': 1880,
#  'jesus': 1641,
#  'metaphorical': 1930,
#  'literal': 1810,
#  'black': 429,
#  'arrested': 286,
#  'philadelphia': 2252,
#  'starbucks': 2865,
#  'settle': 2726,
#  'ice': 1497,
#  'detainer': 900,
#  'issued': 1612,
#  'suspected': 2953,
#  'wine': 3315,
#  'country': 764,
#  'arsonist': 290,
#  'sonoma': 2823,
#  'jail': 1620,
#  'former': 1220,
#  'presidents': 2346,
#  'walk': 3235,
#  'fine': 1170,
#  'line': 1803,
#  'america': 231,
#  'inside': 1554,
#  'snapchat': 2807,
#  'bloodbath': 438,
#  '60': 101,
#  'minutes': 1960,
#  'terror': 3008,
#  'which': 3296,
#  'left': 1765,
#  '17': 32,
#  'dead': 843,
#  'bodies': 444,
#  'classrooms': 649,
#  'kids': 1694,
#  'full': 1246,
#  'blood': 437,
#  'nancy': 2031,
#  'pelosi': 2230,
#  'resign': 2537,
#  'after': 174,
#  'revelations': 2562,
#  'nrtonline': 2095,
#  'donald': 961,
#  'inauguration': 1523,
#  'artists': 292,
#  'perform': 2242,
#  'ceremony': 582,
#  'include': 1526,
#  'elton': 1028,
#  'celine': 577,
#  'dion': 919,
#  'legend': 1769,
#  'leaked': 1757,
#  'picture': 2261,
#  'dragged': 976,
#  'judge': 1664,
#  'handcuffs': 1376,
#  'wiretapping': 3322,
#  'campaign': 525,
#  'official': 2126,
#  'by': 514,
#  'fbi': 1140,
#  'child': 616,
#  'rape': 2435,
#  'trafficking': 3094,
#  'charges': 598,
#  'train': 3097,
#  'news': 2064,
#  'rosa': 2608,
#  'parks': 2203,
#  'granddaughter': 1330,
#  'slams': 2794,
#  'racist': 2425,
#  'democrats': 881,
#  'endorses': 1045,
#  'nra': 2093,
#  'jim': 1646,
#  'porter': 2316,
#  'falsely': 1123,
#  'accused': 137,
#  'saying': 2666,
#  'it': 1614,
#  'only': 2140,
#  'matter': 1886,
#  'time': 3060,
#  'we': 3265,
#  'own': 2183,
#  'colored': 682,
#  'people': 2236,
#  'biden': 415,
#  'raises': 2430,
#  'possibility': 2319,
#  '2020': 67,
#  'presidential': 2345,
#  'bid': 414,
#  'nyc': 2103,
#  'physician': 2256,
#  'wife': 3308,
#  'jump': 1667,
#  'behind': 396,
#  'because': 383,
#  'they': 3034,
#  'afford': 167,
#  'health': 1406,
#  'care': 548,
#  'hours': 1472,
#  'murkowski': 2016,
#  'collins': 678,
#  'every': 1074,
#  'democrat': 879,
#  'voted': 3223,
#  'keep': 1680,
#  'obamacare': 2105,
#  'shutting': 2767,
#  'down': 973,
#  'rice': 2568,
#  'told': 3070,
#  'investigators': 1588,
#  'why': 3304,
#  'unmasked': 3165,
#  'aides': 190,
#  'meryl': 1927,
#  'streep': 2900,
#  'just': 1669,
#  'got': 1319,
#  'major': 1849,
#  'project': 2377,
#  'lying': 1840,
#  'about': 128,
#  'email': 1029,
#  'destroy': 895,
#  'syria': 2964,
#  'israel': 1609,
#  'cnn': 668,
#  'host': 1470,
#  'fareed': 1131,
#  'zakaria': 3365,
#  'calls': 523,
#  'jihad': 1643,
#  'white': 3298,
#  'could': 758,
#  'win': 3314,
#  'nobel': 2076,
#  'peace': 2227,
#  'prize': 2364,
#  'korean': 1712,
#  'peninsula': 2233,
#  'would': 3346,
#  'be': 376,
#  'significant': 2775,
#  'foreign': 1214,
#  'policy': 2299,
#  'achievement': 139,
#  'leaves': 1762,
#  'as': 293,
#  'mueller': 2009,
#  'indictment': 1537,
#  'announced': 246,
#  'illegal': 1505,
#  'muslim': 2019,
#  'iran': 1596,
#  'starting': 2868,
#  'california': 519,
#  'wildfire': 3310,
#  'lawyer': 1747,
#  'claimed': 644,
#  'super': 2937,
#  'bowl': 461,
#  'rigged': 2573,
#  'found': 1224,
#  'japanese': 1627,
#  'whaling': 3291,
#  'crew': 791,
#  'eaten': 1002,
#  'alive': 209,
#  'killer': 1697,
#  'whales': 3290,
#  '16': 29,
#  'barrels': 368,
#  'removed': 2507,
#  'property': 2383,
#  'contain': 737,
#  'parts': 2206,
#  'missing': 1965,
#  'liberal': 1785,
#  'hate': 1391,
#  'me': 1901,
#  'my': 2022,
#  'striking': 2905,
#  'beauty': 381,
#  'intellect': 1566,
#  'kellyanne': 1684,
#  'conway': 746,
#  'buzz': 512,
#  'aldrin': 204,
#  'passes': 2211,
#  'ufo': 3144,
#  'lie': 1790,
#  'detector': 901,
#  'test': 3012,
#  'leaving': 1763,
#  'experts': 1098,
#  'convinced': 745,
#  'that': 3026,
#  'encountered': 1041,
#  'alien': 206,
#  'life': 1792,
#  'text': 3019,
#  'jeff': 1634,
#  'flake': 1187,
#  'speech': 2837,
#  'transcript': 3099,
#  'mike': 1947,
#  'pence': 2232,
#  'allowing': 217,
#  'victims': 3202,
#  'abortions': 127,
#  'lead': 1750,
#  'trying': 3124,
#  'get': 1282,
#  'raped': 2436,
#  'paul': 2219,
#  'ryan': 2636,
#  '22': 71,
#  'americans': 233,
#  'choose': 623,
#  'poor': 2308,
#  'so': 2812,
#  'problem': 2367,
#  'healthy': 1408,
#  'gun': 1355,
#  'owners': 2186,
#  'call': 520,
#  'themselves': 3030,
#  'christian': 625,
#  'anymore': 258,
#  'mayor': 1891,
#  'bhalla': 412,
#  'neon': 2056,
#  'nettle': 2058,
#  'broward': 487,
#  'county': 766,
#  'sheriff': 2743,
#  'parkland': 2202,
#  'tom': 3072,
#  'price': 2354,
#  'better': 409,
#  'budget': 493,
#  'cancer': 534,
#  'patients': 2215,
#  'die': 913,
#  'more': 1987,
#  'quickly': 2418,
#  'greitens': 1337,
#  'admits': 158,
#  'photo': 2254,
#  'session': 2721,
#  'may': 1889,
#  'been': 388,
#  'dream': 978,
#  'administration': 156,
#  'kept': 1689,
#  'mexican': 1933,
#  'detention': 902,
#  'camps': 528,
#  'experiment': 1097,
#  'followers': 1202,
#  'koran': 1710,
#  'same': 2647,
#  'united': 3160,
#  'airlines': 196,
#  'flight': 1192,
#  'attendant': 319,
#  'slaps': 2795,
#  'crying': 808,
#  'baby': 342,
#  'during': 991,
#  'cia': 631,
#  'release': 2499,
#  'documents': 951,
#  'moon': 1985,
#  'than': 3023,
#  '250': 75,
#  'citizens': 638,
#  'how': 1476,
#  'lost': 1830,
#  'war': 3246,
#  'christmas': 627,
#  'thousands': 3044,
#  'killed': 1696,
#  'drops': 983,
#  'tactical': 2970,
#  'nuclear': 2096,
#  'bomb': 449,
#  'charged': 597,
#  'murder': 2013,
#  'driving': 981,
#  'into': 1580,
#  'anti': 253,
#  'far': 1130,
#  'protesters': 2393,
#  'charlottesville': 603,
#  'fox': 1228,
#  'sports': 2844,
#  'cancels': 533,
#  'all': 210,
#  'broadcasts': 482,
#  'until': 3168,
#  'players': 2283,
#  'respect': 2543,
#  'flag': 1186,
#  'legislative': 1771,
#  'process': 2369,
#  'head': 1403,
#  'fines': 1171,
#  'steeler': 2880,
#  'teammates': 2994,
#  'each': 995,
#  'debbie': 849,
#  'wasserman': 3258,
#  'schultz': 2677,
#  'aide': 189,
#  'flee': 1189,
#  'sasha': 2657,
#  'crashed': 783,
#  'her': 1417,
#  'expensive': 1095,
#  'car': 545,
#  'lake': 1724,
#  'sid': 2769,
#  'miller': 1953,
#  'kasich': 1676,
#  'intelligent': 1568,
#  'enough': 1052,
#  'legs': 1773,
#  'closed': 663,
#  'entrust': 1055,
#  'abortion': 126,
#  'decision': 855,
#  'maxine': 1888,
#  'waters': 3262,
#  'shown': 2761,
#  'up': 3169,
#  '10': 5,
#  'congressional': 723,
#  'meetings': 1913,
#  '35': 88,
#  'years': 3356,
#  'gop': 1315,
#  'needs': 2055,
#  'another': 249,
#  '11': 18,
#  'shares': 2733,
#  '_______________': 121,
#  '82': 114,
#  'year': 3354,
#  'old': 2133,
#  'self': 2704,
#  'defense': 866,
#  'gets': 1283,
#  'dea': 842,
#  'raided': 2428,
#  'states': 2871,
#  'senator': 2709,
#  'shocks': 2748,
#  'fires': 1177,
#  'journalist': 1660,
#  'made': 1843,
#  'fun': 1248,
#  'sarah': 2656,
#  'sanders': 2650,
#  'face': 1112,
#  'dhs': 904,
#  'secretary': 2693,
#  'confirms': 719,
#  'preparing': 2340,
#  'sanctuary': 2649,
#  'city': 640,
#  'leaders': 1752,
#  'twelve': 3137,
#  'hurricanes': 1495,
#  'headed': 1404,
#  'towards': 3086,
#  'counts': 765,
#  'do': 947,
#  'support': 2942,
#  'this': 3041,
#  'british': 481,
#  'intelligence': 1567,
#  'seizes': 2703,
#  'foundation': 1225,
#  'warehouse': 3247,
#  'cash': 561,
#  'rudy': 2624,
#  'giuliani': 1296,
#  'officially': 2127,
#  'resigns': 2539,
#  'legal': 1767,
#  'its': 1615,
#  'last': 1735,
#  'leg': 1766,
#  'received': 2458,
#  'shattering': 2737,
#  'doctor': 950,
#  'special': 2835,
#  'report': 2520,
#  'georgia': 1279,
#  'becomes': 385,
#  'state': 2869,
#  'ban': 355,
#  'culture': 810,
#  'historic': 1440,
#  'move': 2000,
#  'restore': 2547,
#  'western': 3289,
#  'values': 3190,
#  'tens': 3004,
#  'scientists': 2681,
#  'declare': 858,
#  'climate': 656,
#  'change': 589,
#  'hoax': 1448,
#  'numbers': 2100,
#  'occupy': 2110,
#  'issue': 1611,
#  'an': 238,
#  'executive': 1085,
#  'order': 2155,
#  'facebook': 1113,
#  'across': 141,
#  'hacked': 1365,
#  'emails': 1030,
#  'center': 579,
#  'russia': 2633,
#  'investigation': 1586,
#  'explained': 1099,
#  'drug': 984,
#  'bust': 507,
#  'lisa': 1806,
#  'page': 2190,
#  'squeals': 2850,
#  'dnc': 946,
#  'server': 2718,
#  'bin': 421,
#  'laden': 1720,
#  'well': 3284,
#  'bahamas': 349,
#  'edward': 1012,
#  'snowden': 2811,
#  'robert': 2586,
#  'redford': 2470,
#  'five': 1185,
#  'prison': 2361,
#  'delta': 874,
#  'ticket': 3054,
#  '2017': 64,
#  'mar': 1866,
#  'lago': 1722,
#  'destroyed': 896,
#  'irma': 1603,
#  'jared': 1628,
#  'kushner': 1716,
#  'still': 2886,
#  'puerto': 2402,
#  'rico': 2572,
#  'facing': 1114,
#  'fraud': 1231,
#  '3m': 91,
#  'federal': 1148,
#  'disaster': 925,
#  'relief': 2501,
#  'dying': 992,
#  '78': 112,
#  'agent': 180,
#  'killing': 1699,
#  'marilyn': 1870,
#  'monroe': 1980,
#  'uncovers': 3150,
#  'evidence': 1077,
#  '62': 106,
#  'voters': 3225,
#  'russian': 2634,
#  'agents': 181,
#  'using': 3182,
#  'toothpaste': 3076,
#  'throw': 3050,
#  'away': 340,
#  'immediately': 1509,
#  'nov': 2088,
#  '28': 81,
#  'queen': 2414,
#  'elizabeth': 1027,
#  'refugees': 2481,
#  'dividing': 944,
#  'nationality': 2038,
#  'fully': 1247,
#  'agree': 185,
#  'video': 3204,
#  'account': 134,
#  'suspended': 2955,
#  'blamed': 433,
#  'sabotaging': 2637,
#  'create': 786,
#  'prank': 2334,
#  'trick': 3111,
#  'your': 3363,
#  'bombshell': 450,
#  'comey': 688,
#  'knew': 1705,
#  'murdered': 2014,
#  'staffer': 2856,
#  'seth': 2724,
#  'rich': 2569,
#  'wikileaks': 3309,
#  'source': 2828,
#  'covered': 775,
#  'american': 232,
#  'under': 3151,
#  'construction': 733,
#  'jennifer': 1638,
#  'aniston': 242,
#  'supporter': 2943,
#  'celebrities': 575,
#  'decide': 854,
#  'make': 1852,
#  'company': 700,
#  'named': 2029,
#  'fight': 1156,
#  'against': 176,
#  'think': 3037,
#  'ne': 2048,
#  'police': 2298,
#  'officers': 2125,
#  'firefighters': 1176,
#  'others': 2168,
#  'hit': 1443,
#  'tax': 2989,
#  'whoopi': 3301,
#  'goldberg': 1308,
#  'navy': 2042,
#  'seal': 2687,
#  'widow': 3307,
#  'looking': 1826,
#  'attention': 321,
#  'placed': 2273,
#  'floor': 1193,
#  'customer': 818,
#  'step': 2882,
#  'food': 1204,
#  'stamp': 2858,
#  'enrollment': 1053,
#  'four': 1227,
#  'month': 1982,
#  'goes': 1306,
#  'g20': 1255,
#  'summit': 2935,
#  'melania': 1915,
#  'hired': 1436,
#  'exorcist': 1089,
#  'cleanse': 651,
#  'house': 1473,
#  'demons': 882,
#  'urgent': 3175,
#  'proposed': 2386,
#  'law': 1744,
#  'charge': 596,
#  'terrorism': 3009,
#  'fact': 1115,
#  'check': 604,
#  'no': 2074,
#  'fall': 1122,
#  'river': 2582,
#  'massachusetts': 1881,
#  'built': 498,
#  'immigrants': 1511,
#  'clint': 658,
#  'eastwood': 1001,
#  'his': 1438,
#  'estate': 1063,
#  'actor': 147,
#  'brad': 466,
#  'pitt': 2269,
#  'future': 1253,
#  'find': 1167,
#  '19': 37,
#  'female': 1154,
#  'freezers': 1235,
#  'lives': 1813,
#  'carved': 559,
#  'skin': 2791,
#  'deputy': 890,
#  'attorney': 322,
#  'general': 1273,
#  'rod': 2594,
#  'rosenstein': 2612,
#  'raising': 2431,
#  'questions': 2417,
#  'fate': 1135,
#  'jefferson': 1635,
#  'davis': 838,
#  'statue': 2873,
#  'replaced': 2518,
#  'likeness': 1797,
#  'hagee': 1367,
#  'prosecuting': 2387,
#  'say': 2665,
#  'name': 2028,
#  'intercourse': 1570,
#  'kardashians': 1675,
#  'donate': 962,
#  'whopping': 3302,
#  'sum': 2931,
#  'las': 1734,
#  'vegas': 3193,
#  'shooting': 2752,
#  'colorado': 681,
#  'rockies': 2592,
#  'baseball': 372,
#  'sell': 2705,
#  'marijuana': 1869,
#  'brownies': 489,
#  'concession': 710,
#  'stands': 2862,
#  'mitt': 1969,
#  'romney': 2600,
#  'some': 2821,
#  'very': 3196,
#  'serious': 2716,
#  'emotional': 1035,
#  'problems': 2368,
#  'removes': 2508,
#  'implement': 1518,
#  'sharia': 2734,
#  'autopsy': 333,
#  'results': 2549,
#  'vince': 3208,
#  'foster': 1223,
#  'exhumed': 1086,
#  'body': 445,
#  'cause': 569,
#  'changed': 590,
#  'bill': 416,
#  'gates': 1263,
#  'go': 1303,
#  'history': 1442,
#  'greatest': 1335,
#  'reagan': 2447,
#  'florida': 1194,
#  'bridge': 477,
#  'collapse': 676,
#  'hrc': 1480,
#  'caught': 568,
#  'tape': 2982,
#  'laughing': 1739,
#  'wiping': 3319,
#  'out': 2170,
#  'those': 3043,
#  'hillbillies': 1432,
#  'alabama': 201,
#  'poll': 2306,
#  'workers': 3340,
#  'birmingham': 423,
#  'hollywood': 1455,
#  'celebs': 576,
#  'total': 3082,
#  'strike': 2904,
#  'does': 952,
#  'falsification': 1124,
#  'chef': 608,
#  'quits': 2420,
#  'fast': 1132,
#  'months': 1984,
#  '112': 21,
#  'north': 2083,
#  'carolina': 554,
#  'denzel': 884,
#  'washington': 3257,
#  'fake': 1120,
#  'story': 2895,
#  'nasa': 2034,
#  '18000': 35,
#  'usd': 3179,
#  'stay': 2876,
#  'bed': 386,
#  'smoke': 2805,
#  'weed': 3276,
#  '70': 108,
#  'straight': 2896,
#  'days': 840,
#  'taken': 2972,
#  'office': 2123,
#  'plans': 2279,
#  'within': 3326,
#  'next': 2068,
#  '30': 84,
#  'listen': 1808,
#  'curious': 814,
#  'robocall': 2589,
#  'seeks': 2700,
#  'damaging': 831,
#  'information': 1549,
#  'national': 2037,
#  'guard': 1350,
#  'storms': 2894,
#  'mexico': 1934,
#  'border': 456,
#  'makes': 1853,
#  'game': 1259,
#  'changing': 593,
#  'impact': 1513,
#  'moves': 2003,
#  'recount': 2464,
#  'massive': 1883,
#  'voter': 3224,
#  'details': 898,
#  'shep': 2741,
#  'smith': 2804,
#  'canned': 538,
#  'control': 739,
#  '000': 0,
#  'pound': 2326,
#  'great': 1334,
#  'shark': 2735,
#  'captured': 544,
#  'lakes': 1725,
#  'massacre': 1882,
#  'victim': 3201,
#  'saved': 2663,
#  'expelled': 1093,
#  'harvard': 1386,
#  'bachmann': 344,
#  'suffered': 2927,
#  'blacks': 431,
#  'did': 911,
#  'couple': 767,
#  'slavery': 2798,
#  'babysitter': 343,
#  'crystal': 809,
#  'meth': 1931,
#  'eats': 1004,
#  'contact': 736,
#  'kerry': 1690,
#  'palin': 2195,
#  'coma': 684,
#  'run': 2627,
#  'globalist': 1300,
#  'security': 2696,
#  'threat': 3045,
#  '2014': 61,
#  'targeted': 2985,
#  'online': 2139,
#  'free': 1233,
#  'airline': 195,
#  'scam': 2668,
#  'shocking': 2747,
#  'announcement': 247,
#  'saw': 2664,
#  'coming': 689,
#  'canceled': 532,
#  'reinstated': 2493,
#  'sacred': 2639,
#  'day': 839,
#  'uspostman': 3183,
#  'com': 683,
#  'postman': 2322,
#  'bumble': 501,
#  'bee': 387,
#  'foods': 1205,
#  'cooked': 747,
#  'tuna': 3128,
#  'morgue': 1989,
#  'employee': 1036,
#  'cremated': 789,
#  'mistake': 1966,
#  'while': 3297,
#  'taking': 2974,
#  'nap': 2032,
#  'furious': 1252,
#  'gift': 1288,
#  'sent': 2713,
#  'hospital': 1469,
#  'stephen': 2884,
#  'bannon': 359,
#  'nobody': 2077,
#  'blame': 432,
#  'beating': 380,
#  'love': 1832,
#  'emma': 1034,
#  'gonzález': 1311,
#  'went': 3286,
#  'viral': 3211,
#  'where': 3294,
#  'teens': 2999,
#  'villains': 3207,
#  'nation': 2036,
#  'majorthoughts': 1851,
#  'revamping': 2559,
#  'military': 1951,
#  're': 2444,
#  'bringing': 480,
#  'draft': 975,
#  'representatives': 2523,
#  'promise': 2380,
#  'un': 3146,
#  'billionaire': 418,
#  'refused': 2482,
#  'vaccinate': 3185,
#  'children': 617,
#  'haiti': 1369,
#  'getting': 1284,
#  'ready': 2446,
#  'testify': 3014,
#  'corruption': 754,
#  'week': 3277,
#  'gunshot': 1359,
#  'picks': 2259,
#  'sides': 2770,
#  'senate': 2708,
#  'race': 2422,
#  'shuts': 2766,
#  'gateway': 1264,
#  'pundit': 2405,
#  'breitbart': 475,
#  'reports': 2522,
#  'discredited': 931,
#  'allred': 218,
#  'cannibals': 539,
#  'claim': 643,
#  'eating': 1003,
#  'human': 1489,
#  'flesh': 1191,
#  'cures': 813,
#  'diabetes': 905,
#  'depression': 889,
#  'laguna': 1723,
#  'beach': 377,
#  'antifa': 254,
#  '22m': 72,
#  'david': 837,
#  'hogg': 1450,
#  'didn': 912,
#  'attend': 318,
#  'high': 1424,
#  ...}

# %%
labels = y == "real"
labels = labels.astype(int)
labels
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1051    1
# 1052    1
# 1053    1
# 1054    1
# 1055    1
# Name: label, Length: 1056, dtype: int32

# %%
### Run your classifier

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import pandas as pd 
import numpy as np 
from sklearn.model_selection import cross_val_predict

df = pd.read_csv('politifact.csv')
#df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()

from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

vectorizer.fit(X)
transformed = vectorizer.transform(X)
#transformed

labels = y == "real"
#labels=y
labels = labels.astype(int)
#labels

X_train, X_test, y_train, y_test = train_test_split(transformed,labels, test_size=0.2,random_state=25)

clf= SVC(kernel="linear")
#svc = svm.SVC (C = 1, kernel = 'linear')
#clf = svc.fit (transformed, labels)
clf.fit(X_train, y_train)
preds = clf.predict(X_test)
#predicted = cross_val_predict(clf,transformed, labels,cv=5)

print ("Accuracy: ")
print (accuracy_score(y_test, preds))
#print((preds == y_test).sum()/len(y_test))
print ("precision: ")
#print (precision_score(labels, predicted, average="weighted"))
print (precision_score(y_test, preds))
print ("recall: ")
print (recall_score(y_test, preds))

print ("f1 ")
print (f1_score(y_test, preds))
# Out:
# Accuracy:
# 0.7783018867924528
# precision:
# 0.7925925925925926
# recall:
# 0.8492063492063492
# f1
# 0.8199233716475095

# %%
from sklearn.naive_bayes import GaussianNB

clf2 = GaussianNB()
clf2.fit(X_train.todense(), y_train)
preds = clf2.predict(X_test.todense())
#(preds == y_test).sum()/len(y_test)
print ("Accuracy: ")
print (accuracy_score(y_test, preds))
print ("precision: ")
#print (precision_score(labels, predicted, average="weighted"))
print (precision_score(y_test, preds))
print ("recall: ")
print (recall_score(y_test, preds))

print ("f1 ")
print (f1_score(y_test, preds))
# Out:
# Accuracy:
# 0.7924528301886793
# precision:
# 0.8306451612903226
# recall:
# 0.8174603174603174
# f1
# 0.824

# %%
### TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
transformed = tfidf.fit_transform(X)
transformed
# Out:
# <1967x48683 sparse matrix of type '<class 'numpy.float64'>'
# 	with 692360 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(transformed,labels, test_size=0.3, random_state=24)



clf= SVC(kernel="linear")
clf.fit(X_train, y_train)
preds = clf.predict(X_test)


(preds == y_test).sum()/len(y_test)
# Out:
# 0.9069373942470389

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(clf,transformed, labels, cv=5).mean()
# Out:
# 0.90084989860632125

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(clf,X_train, y_train, cv=5).mean()
# Out:
# 0.88587282536568479

# %%
X_train.shape
# Out:
# (1376, 48683)

# %%
1767-1376
# Out:
# 391

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
import pandas as pd 
import numpy as np 
from sklearn.model_selection import cross_val_predict

df = pd.read_csv('politifact.csv')
#df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()

from sklearn.feature_extraction.text import CountVectorizer


vectorizer = CountVectorizer()

vectorizer.fit(X)
transformed = vectorizer.transform(X)
#transformed

labels = y == "real"
#labels=y
labels = labels.astype(int)
#labels

X_train, X_test, y_train, y_test = train_test_split(transformed,labels, test_size=0.2,random_state=25)
#clf_knn.fit(X, y)
clf_tree = tree.DecisionTreeClassifier()
clf_tree.fit(X_train, y_train)
preds = clf_tree.predict(X_test)
#predicted = cross_val_predict(clf,transformed, labels,cv=5)

print ("Accuracy: ")
print (accuracy_score(y_test, preds))
#print((preds == y_test).sum()/len(y_test))
print ("precision: ")
#print (precision_score(labels, predicted, average="weighted"))
print (precision_score(y_test, preds))
print ("recall: ")
print (recall_score(y_test, preds))

print ("f1 ")
print (f1_score(y_test, preds))
# Out:
# Accuracy:
# 0.7924528301886793
# precision:
# 0.8106060606060606
# recall:
# 0.8492063492063492
# f1
# 0.8294573643410852
